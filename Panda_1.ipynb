# %% [markdown]
# <a href="https://colab.research.google.com/github/andreMarquesWeds/starter-workflows/blob/master/Panda_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
#!dir *.ipynb - dos
# !ls -la
# Out:
# total 164
# drwxr-xr-x 1 root root   4096 Jun 16 14:59 .
# drwxr-xr-x 1 root root   4096 Jun 16 14:59 ..
# drwxr-xr-x 4 root root   4096 Jun 13 13:27 .config
# -rw-r--r-- 1 root root 148243 Jun 16 14:59 Credit.csv
# drwxr-xr-x 1 root root   4096 Jun 13 13:28 sample_data

# %%
from google.colab import files

carregado = files.upload()

# %%
#carrega arquivo para dataframe Pandas
dados = pd.read_csv("Credit.csv")

#formato
dados.shape
# Out:
# (1000, 21)

# %%
# primeiros registros
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
# resumo estatístico de colunas numéricas
dados.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
# últimos registros, com parâmetros
dados.tail(2)
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# 998                 none  'for free'                1  skilled              1
# 999                 none         own                1  skilled              1
#
#      own_telephone foreign_worker class
# 998            yes            yes   bad
# ...

# %%
# filtras por nome da coluna
dados[["duration","purpose"]]
# Out:
#      duration              purpose
# 0           6             radio/tv
# 1          48             radio/tv
# 2          12            education
# 3          42  furniture/equipment
# 4          24            'new car'
# ..        ...                  ...
# 995        12  furniture/equipment
# 996        30           'used car'
# 997        12             radio/tv
# 998        45             radio/tv
# 999        45           'used car'
#
# [1000 rows x 2 columns]

# %%
# filtrar linhas por indice
dados.loc[1:3]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
#
#    property_magnitude age  other_payment_plans     housing existing_credits  \
# 1       'real estate'  22                 none         own                1
# ...

# %%
#linhas 1 e 3
dados.loc[[1,3]]

# %% [markdown]
# Filtros

# %%
# filtro
dados.loc[dados['purpose'] == "radio/tv"]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
# Filtrar as linhas onde a coluna 'cidade' contém qualquer padrão que comece com 'r'
dados.loc[dados['purpose'].str.contains('^r', case=False, na=False)]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
# outra condição
dados.loc[dados['credit_amount'] >  18000]
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
# outra condição AND
dados.loc[(dados['credit_amount'] >  15000) & (dados['duration'] >=60)]
# Out:
#     checking_status  duration        credit_history   purpose  credit_amount  \
# 637   'no checking'        60  'delayed previously'  radio/tv          15653
#
#     savings_status employment  installment_commitment personal_status  \
# 637           <100     4<=X<7                       2   'male single'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 637          none  ...                 car  21                 none     own
#
#     existing_credits      job num_dependents  own_telephone foreign_worker  \
# 637                2  skilled              1            yes            yes
#
#     class
# 637  good
#
# [1 rows x 21 columns]

# %%
# outra condição OR
dados.loc[(dados['credit_amount'] >  15000) | (dados['purpose'] == 'other')]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 72               <0         8  'critical/other existing credit'     other
# 83               <0        24                   'existing paid'     other
# 95         0<=X<200        54             'no credits/all paid'  business
# 105        0<=X<200        24  'critical/other existing credit'     other
# 287        0<=X<200        48              'delayed previously'     other
# 310        0<=X<200        48                   'existing paid'     other
# 374        0<=X<200        60                        'all paid'     other
# 431        0<=X<200        24                   'existing paid'     other
# 442        0<=X<200        20              'delayed previously'     other
# 594              <0        24                        'all paid'     other
# 637   'no checking'        60              'delayed previously'  radio/tv
# 665   'no checking'        24  'critical/other existing credit'     other
# ...

# %%
# atribuimos resultado a variável, criando outro df
credito2 = dados.loc[dados['credit_amount'] >  18000]
print(credito2)
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
# definimos só algumas colunas
credito3 = dados[['checking_status','duration']].loc[dados['credit_amount'] >  18000]
print(credito3)
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
# séries, única coluna
# pode ser criada a partir de listas, array do numpy ou coluna de data frame
s1 = pd.Series([2, 5, 3, 34, 54, 23, 1, 16])
print(s1)
print(type(s1))
# Out:
# 0     2
# 1     5
# 2     3
# 3    34
# 4    54
# 5    23
# 6     1
# 7    16
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# serie a partir de um array do numpy
import numpy as np
array1 = np.array([2, 5, 3, 34, 54, 23, 1, 16])
s2 = pd.Series(array1)
print(s2)
print(type(s2))
# Out:
# 0     2
# 1     5
# 2     3
# 3    34
# 4    54
# 5    23
# 6     1
# 7    16
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# series a partir de um dataframe
s3 = dados['purpose']
print(s3)
type(s3)
print(type(s3))
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# note a diferença, temos um data frame
d4= dados[['purpose']]
print(d4)
type(d4)
# Out:
#                  purpose
# 0               radio/tv
# 1               radio/tv
# 2              education
# 3    furniture/equipment
# 4              'new car'
# ..                   ...
# 995  furniture/equipment
# 996           'used car'
# 997             radio/tv
# 998             radio/tv
# 999           'used car'
#
# [1000 rows x 1 columns]
# pandas.core.frame.DataFrame

# %%
dados
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %% [markdown]
# Renomear

# %%
# renomear
dados.rename(columns={"duration":"duração","purpose":"propósito"})
# Out:
#     checking_status  duração                    credit_history  \
# 0                <0        6  'critical/other existing credit'
# 1          0<=X<200       48                   'existing paid'
# 2     'no checking'       12  'critical/other existing credit'
# 3                <0       42                   'existing paid'
# 4                <0       24              'delayed previously'
# ..              ...      ...                               ...
# 995   'no checking'       12                   'existing paid'
# 996              <0       30                   'existing paid'
# 997   'no checking'       12                   'existing paid'
# 998              <0       45                   'existing paid'
# 999        0<=X<200       45  'critical/other existing credit'
#
#                propósito  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
# porém a alteração não é persistida
dados.head(1)
# Out:
#   checking_status  duration                    credit_history   purpose  \
# 0              <0         6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
# para persistir
dados.rename(columns={"duration":"duração", "purpose":"propósito"}, inplace=True)

# %%
dados.head(1)
# Out:
#   checking_status  duração                    credit_history propósito  \
# 0              <0        6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
# excluir coluna
dados.drop('checking_status', axis=1, inplace=True) # axis=1 para coluna // tb pode usar assim: df.drop(columns=['B', 'C'])

print(dados)
# Out:
#      duração                    credit_history            propósito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
dados.head(1)
# Out:
#    duração                    credit_history propósito  credit_amount  \
# 0        6  'critical/other existing credit'  radio/tv           1169
#
#        savings_status employment  installment_commitment personal_status  \
# 0  'no known savings'        >=7                       4   'male single'
#
#   other_parties  residence_since property_magnitude  age other_payment_plans  \
# 0          none                4      'real estate'   67                none
#
#   housing  existing_credits      job  num_dependents own_telephone  \
# 0     own                 2  skilled               1           yes
#
#   foreign_worker class
# 0            yes  good

# %%
# verificar dados nulos
dados.isnull()
# Out:
#      duração  credit_history  propósito  credit_amount  savings_status  \
# 0      False           False      False          False           False
# 1      False           False      False          False           False
# 2      False           False      False          False           False
# 3      False           False      False          False           False
# 4      False           False      False          False           False
# ..       ...             ...        ...            ...             ...
# 995    False           False      False          False           False
# 996    False           False      False          False           False
# 997    False           False      False          False           False
# 998    False           False      False          False           False
# 999    False           False      False          False           False
#
#      employment  installment_commitment  personal_status  other_parties  \
# ...

# %%
# verificar dados nulos
dados.isnull().sum()
# Out:
# duração                   0
# credit_history            0
# propósito                 0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
dados.shape
# Out:
# (1000, 20)

# %%
# retirar colunas com NaN
# Tomar cuidado, pois irá apagar linhas que tiverem NaN
dados.dropna()
# Out:
#      duração                    credit_history            propósito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
dados.shape
# Out:
# (1000, 20)

# %%
# preencher dados faltantes
dados['duração'].fillna(0, inplace = True)

# %%
dados
# Out:
#      duração                    credit_history            propósito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %% [markdown]
# ### loc vs iloc
# ##
# ### https://stackoverflow.com/questions/28757389/pandas-loc-vs-iloc
# ##
# ### loc usado para nomes e iloc para posição

# %%
dados.iloc[0:3,0:5]
# Out:
#    duração                    credit_history  propósito  credit_amount  \
# 0        6  'critical/other existing credit'   radio/tv           1169
# 1       48                   'existing paid'   radio/tv           5951
# 2       12  'critical/other existing credit'  education           2096
#
#        savings_status
# 0  'no known savings'
# 1                <100
# 2                <100

# %%
dados.iloc[[0, 1, 2, 3, 7], 0:5]
# Out:
#    duração                    credit_history            propósito  \
# 0        6  'critical/other existing credit'             radio/tv
# 1       48                   'existing paid'             radio/tv
# 2       12  'critical/other existing credit'            education
# 3       42                   'existing paid'  furniture/equipment
# 7       36                   'existing paid'           'used car'
#
#    credit_amount      savings_status
# 0           1169  'no known savings'
# 1           5951                <100
# 2           2096                <100
# 3           7882                <100
# 7           6948                <100

# %%
# Exemplo de dados
dados = pd.DataFrame({'coluna_existente': [1, 2, 3, 4, 5]})
print(dados)
# Out:
#    coluna_existente
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5

# %%
# Aplicando o filtro
filtro = dados['coluna_existente'] > 3
filtro
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: coluna_existente, dtype: bool

# %%
# Criando uma nova coluna com base no filtro
dados.loc[filtro, 'nova_coluna'] = 'maior que 3'

# %%
dados
# Out:
#    coluna_existente  nova_coluna
# 0                 1          NaN
# 1                 2          NaN
# 2                 3          NaN
# 3                 4  maior que 3
# 4                 5  maior que 3

# %%
# Preenchendo os valores que não atendem ao filtro com outro valor
dados['nova_coluna'].fillna('menor ou igual a 3', inplace=True)

# %%
print(dados)
# Out:
#    coluna_existente         nova_coluna
# 0                 1  menor ou igual a 3
# 1                 2  menor ou igual a 3
# 2                 3  menor ou igual a 3
# 3                 4         maior que 3
# 4                 5         maior que 3

# %% [markdown]
# ### Agrupamento

# %%
# Exemplo de dados
dados = pd.DataFrame({'grupo': ['A', 'A', 'B', 'B', 'A'],
                      'valor': [1, 2, 3, 4, 5],
                      'quant': [10, 20, 30, 40, 50]})

# Agrupando os dados por 'grupo' e calculando a média dos valores para cada grupo
media_por_grupo = dados.groupby('grupo')['quant'].mean()

print(media_por_grupo)
# Out:
# grupo
# A    26.666667
# B    35.000000
# Name: quant, dtype: float64

# %% [markdown]
# ### Apply

# %%
# Exemplo de dados
dados = pd.DataFrame({'valores': [1, 2, 3, 4, 5]})

# Função para calcular o quadrado de um número
def calcular_quadrado(x):
    return x ** 2

# Aplicando a função 'calcular_quadrado' à coluna 'valores' usando apply
dados['quadrado'] = dados['valores'].apply(calcular_quadrado)

print(dados)
# Out:
#    valores  quadrado
# 0        1         1
# 1        2         4
# 2        3         9
# 3        4        16
# 4        5        25

# %% [markdown]
# ### Merge

# %%
# DataFrame com informações sobre os alunos
alunos = pd.DataFrame({
    'student_id': [1, 2, 3, 4],
    'nome': ['João', 'Maria', 'Pedro', 'Ana']
})

# DataFrame com informações sobre as disciplinas
disciplinas = pd.DataFrame({
    'student_id': [1, 2, 2, 3, 4],
    'disciplina': ['Matemática', 'Física', 'Química', 'História', 'Geografia']
})

# Combinando os DataFrames usando merge
resultado = pd.merge(alunos, disciplinas, on='student_id')

print(resultado)
# Out:
#    student_id   nome  disciplina
# 0           1   João  Matemática
# 1           2  Maria      Física
# 2           2  Maria     Química
# 3           3  Pedro    História
# 4           4    Ana   Geografia

# %%
# Left join

# DataFrame de exemplo para alunos
alunos = pd.DataFrame({
    'student_id': [1, 2, 3, 4],
    'nome': ['João', 'Maria', 'Pedro', 'Ana']
})

# DataFrame de exemplo para notas
notas = pd.DataFrame({
    'student_id': [1, 2, 3],
    'nota': [8, 7, 9]
})

# Left join entre alunos e notas
left_join = pd.merge(alunos, notas, on='student_id', how='left')

print("Left join:")
print(left_join)

# Right join entre alunos e notas
right_join = pd.merge(alunos, notas, on='student_id', how='right')

print("\nRight join:")
print(right_join)
# Out:
# Left join:
#    student_id   nome  nota
# 0           1   João   8.0
# 1           2  Maria   7.0
# 2           3  Pedro   9.0
# 3           4    Ana   NaN
#
# Right join:
#    student_id   nome  nota
# 0           1   João     8
# 1           2  Maria     7
# 2           3  Pedro     9

# %% [markdown]
# ### Query

# %%
# Exemplo de dados
dados = pd.DataFrame({
    'idade': [25, 35, 45, 30, 40],
    'salário': [40000, 60000, 70000, 45000, 55000]
})

# Usando query para selecionar as linhas onde a idade é maior que 30 e o salário é maior que 50000
resultado = dados.query('idade > 30 and salário > 50000')

print(resultado)
# Out:
#    idade  salário
# 1     35    60000
# 2     45    70000
# 4     40    55000
